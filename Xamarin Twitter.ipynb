# %%
import pandas as pd
import tweepy       # python wrapper for twitter api
import json
import time
import requests
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
api_key = 'NAw1wegVEZueRDqyA27c0pjjT'
api_secret = '0IbLwj3CPnsMs6xDPrRtjLDPvLAuYT1US6bgM5pvSlRemIFwrl'
access_token = '3278767399-BzpJJJxsA64HQqxPHRrjIaoNaPrz0mxfsOnl2Qu'
access_secret = 'Q2B7TbCNkZUTEsXfmFtpx9GlnMk3SimvW7WKmJC2waV0o'

# %%
auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth)

# %%
tweets = api.search(q = '#xamarin')
#tweets = api.search(show_user = 'xamarinhq')
#tweets = api.get_user(id = 'xamarinhq')

# %%
tweets
# Out:
# [Status(contributors=None, truncated=False, text=u'RT @ozaksuty: #Xamarin stable update geldi. Cycle 8 Service bug fix yap\u0131ld\u0131. Detaylar i\xe7in https://t.co/ic33Od3cZu', is_quote_status=False, in_reply_to_status_id=None, id=783882946956685312, favorite_count=0, _api=<tweepy.api.API object at 0x11572e6d0>, author=User(follow_request_sent=False, has_extended_profile=True, profile_use_background_image=True, _json={u'follow_request_sent': False, u'has_extended_profile': True, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 368854135, u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme17/bg.gif', u'verified': False, u'profile_text_color': u'000000', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/773572778452811776/hLBD3xe9_normal.jpg', u'profile_sidebar_fill_color': u'000000', u'entities': {u'url': {u'urls': [{u'url': u'http://t.co/4OM2NI3fpM', u'indices': [0, 22], u'expanded_url': u'http://www.pa
# ...
