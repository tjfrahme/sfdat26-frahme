# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
county_facts = pd.read_csv('county_facts.csv')

# %%
county_dict = pd.read_csv('county_facts_dictionary.csv')

# %%
primary_results = pd.read_csv('primary_results.csv')

# %%
county_facts
# Out:
#        fips           area_name state_abbreviation  PST045214  PST040210  \
# 0         0       United States                NaN  318857056  308758105
# 1      1000             Alabama                NaN    4849377    4780127
# 2      1001      Autauga County                 AL      55395      54571
# 3      1003      Baldwin County                 AL     200111     182265
# 4      1005      Barbour County                 AL      26887      27457
# 5      1007         Bibb County                 AL      22506      22919
# 6      1009       Blount County                 AL      57719      57322
# 7      1011      Bullock County                 AL      10764      10915
# 8      1013       Butler County                 AL      20296      20946
# 9      1015      Calhoun County                 AL     115916     118586
# 10     1017     Chambers County                 AL      34076      34170
# 11     1019     Cherokee County                 AL      26037      25986
# ...

# %%
county_dict
# Out:
#    column_name                                        description
# 0    PST045214                          Population, 2014 estimate
# 1    PST040210          Population, 2010 (April 1) estimates base
# 2    PST120214  Population, percent change - April 1, 2010 to ...
# 3    POP010210                                   Population, 2010
# 4    AGE135214               Persons under 5 years, percent, 2014
# 5    AGE295214              Persons under 18 years, percent, 2014
# 6    AGE775214           Persons 65 years and over, percent, 2014
# 7    SEX255214                      Female persons, percent, 2014
# 8    RHI125214                         White alone, percent, 2014
# 9    RHI225214     Black or African American alone, percent, 2014
# 10   RHI325214  American Indian and Alaska Native alone, perce...
# 11   RHI425214                         Asian alone, percent, 2014
# 12   RHI525214  Native Hawaiian and Other Pacific Islander alo...
# ...

# %%
rep_results = primary_results[primary_results.party == 'Republican']
rep_results = rep_results[rep_results.votes != 0]
rep_results
# Out:
#                state state_abbreviation     county    fips       party  \
# 8959         Alabama                 AL    Autauga  1001.0  Republican
# 8960         Alabama                 AL    Autauga  1001.0  Republican
# 8961         Alabama                 AL    Autauga  1001.0  Republican
# 8962         Alabama                 AL    Autauga  1001.0  Republican
# 8963         Alabama                 AL    Autauga  1001.0  Republican
# 8964         Alabama                 AL    Baldwin  1003.0  Republican
# 8965         Alabama                 AL    Baldwin  1003.0  Republican
# 8966         Alabama                 AL    Baldwin  1003.0  Republican
# 8967         Alabama                 AL    Baldwin  1003.0  Republican
# 8968         Alabama                 AL    Baldwin  1003.0  Republican
# 8969         Alabama                 AL    Barbour  1005.0  Republican
# 8970         Alabama                 AL    Barbour  1005.0  Republican
# ...

# %%
rep_results = rep_results.dropna()

# %%
rep_results
# Out:
#          state state_abbreviation                county        fips  \
# 8959   Alabama                 AL               Autauga      1001.0
# 8960   Alabama                 AL               Autauga      1001.0
# 8961   Alabama                 AL               Autauga      1001.0
# 8962   Alabama                 AL               Autauga      1001.0
# 8963   Alabama                 AL               Autauga      1001.0
# 8964   Alabama                 AL               Baldwin      1003.0
# 8965   Alabama                 AL               Baldwin      1003.0
# 8966   Alabama                 AL               Baldwin      1003.0
# 8967   Alabama                 AL               Baldwin      1003.0
# 8968   Alabama                 AL               Baldwin      1003.0
# 8969   Alabama                 AL               Barbour      1005.0
# 8970   Alabama                 AL               Barbour      1005.0
# 8971   Alabama                 AL               Barbour      1005.0
# ...

# %%
donald_county = rep_results[(rep_results.candidate == 'Donald Trump') & (rep_results.victory == 1) ]
donald_county
# Out:
#          state state_abbreviation          county        fips       party  \
# 8959   Alabama                 AL         Autauga      1001.0  Republican
# 8964   Alabama                 AL         Baldwin      1003.0  Republican
# 8969   Alabama                 AL         Barbour      1005.0  Republican
# 8974   Alabama                 AL            Bibb      1007.0  Republican
# 8979   Alabama                 AL          Blount      1009.0  Republican
# 8984   Alabama                 AL         Bullock      1011.0  Republican
# 8989   Alabama                 AL          Butler      1013.0  Republican
# 8994   Alabama                 AL         Calhoun      1015.0  Republican
# 8999   Alabama                 AL        Chambers      1017.0  Republican
# 9004   Alabama                 AL        Cherokee      1019.0  Republican
# 9009   Alabama                 AL         Chilton      1021.0  Republican
# 9014   Alabama                 AL         Choctaw      1023.0  Republican
# ...

# %%
not_donald_county = rep_results[(rep_results.candidate != 'Donald Trump') & (rep_results.victory == 1) ]

# %%
not_donald_county
# Out:
#           state state_abbreviation                county        fips  \
# 9306    Arizona                 AZ                Graham      4009.0
# 9354   Arkansas                 AR                Benton      5007.0
# 9384   Arkansas                 AR                 Clark      5019.0
# 9399   Arkansas                 AR             Cleveland      5025.0
# 9414   Arkansas                 AR             Craighead      5031.0
# 9419   Arkansas                 AR              Crawford      5033.0
# 9449   Arkansas                 AR              Faulkner      5045.0
# 9469   Arkansas                 AR                 Grant      5053.0
# 9479   Arkansas                 AR             Hempstead      5057.0
# 9549   Arkansas                 AR                Lonoke      5085.0
# 9564   Arkansas                 AR                Miller      5091.0
# 9584   Arkansas                 AR                Nevada      5099.0
# 9599   Arkansas                 AR                 Perry      5105.0
# ...

# %%
##  County Information

# %%
main = main[pd.notnull(main['state_abbreviation'])]
main
# Out:
#        fips           area_name state_abbreviation  PST045214  PST040210  \
# 2      1001      Autauga County                 AL      55395      54571
# 3      1003      Baldwin County                 AL     200111     182265
# 4      1005      Barbour County                 AL      26887      27457
# 5      1007         Bibb County                 AL      22506      22919
# 6      1009       Blount County                 AL      57719      57322
# 7      1011      Bullock County                 AL      10764      10915
# 8      1013       Butler County                 AL      20296      20946
# 9      1015      Calhoun County                 AL     115916     118586
# 10     1017     Chambers County                 AL      34076      34170
# 11     1019     Cherokee County                 AL      26037      25986
# 12     1021      Chilton County                 AL      43931      43631
# 13     1023      Choctaw County                 AL      13323      13858
# ...

# %%
county_dict
# Out:
#    column_name                                        description
# 0    PST045214                          Population, 2014 estimate
# 1    PST040210          Population, 2010 (April 1) estimates base
# 2    PST120214  Population, percent change - April 1, 2010 to ...
# 3    POP010210                                   Population, 2010
# 4    AGE135214               Persons under 5 years, percent, 2014
# 5    AGE295214              Persons under 18 years, percent, 2014
# 6    AGE775214           Persons 65 years and over, percent, 2014
# 7    SEX255214                      Female persons, percent, 2014
# 8    RHI125214                         White alone, percent, 2014
# 9    RHI225214     Black or African American alone, percent, 2014
# 10   RHI325214  American Indian and Alaska Native alone, perce...
# 11   RHI425214                         Asian alone, percent, 2014
# 12   RHI525214  Native Hawaiian and Other Pacific Islander alo...
# ...
